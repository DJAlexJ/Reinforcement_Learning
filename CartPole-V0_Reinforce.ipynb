# %%
import sys
import torch  
import gym
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
# Constants
GAMMA = 0.9

class PolicyNetwork(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(PolicyNetwork, self).__init__()

        self.num_actions = num_actions
        self.linear1 = nn.Linear(num_inputs, hidden_size)
        self.linear2 = nn.Linear(hidden_size, num_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, state):
        x = F.relu(self.linear1(state))
        x = F.softmax(self.linear2(x), dim=1)
        return x 
    
    def get_action(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0)
        probs = self.forward(Variable(state))
        #Choose action with regard to policy
        highest_prob_action = np.random.choice(self.num_actions, p=np.squeeze(probs.detach().numpy()))
        log_prob = torch.log(probs.squeeze(0)[highest_prob_action]) #log for gradient
        return highest_prob_action, log_prob

# %%
def update_policy(policy_network, rewards, log_probs):
    discounted_rewards = []

    for t in range(len(rewards)):
        Gt = 0 
        pw = 0
        for r in rewards[t:]:
            Gt = Gt + GAMMA**pw * r
            pw = pw + 1
        discounted_rewards.append(Gt)
        
    discounted_rewards = torch.tensor(discounted_rewards)
    discounted_rewards = (discounted_rewards - discounted_rewards.mean()) / (discounted_rewards.std() + 1e-9) # normalize discounted rewards

    policy_gradient = []
    for log_prob, Gt in zip(log_probs, discounted_rewards):
        policy_gradient.append(-log_prob * Gt)
    
    policy_network.optimizer.zero_grad()
    policy_gradient = torch.stack(policy_gradient).sum()
    policy_gradient.backward()
    policy_network.optimizer.step()

# %%
env = gym.make('CartPole-v0')
policy_net = PolicyNetwork(env.observation_space.shape[0], env.action_space.n, 128)
    
max_episode_num = 3000
max_steps = 10000
numsteps = []
avg_numsteps = []
all_rewards = []

for episode in range(max_episode_num):
    state = env.reset()
    log_probs = []
    rewards = []

    for steps in range(max_steps):
        env.render()
        action, log_prob = policy_net.get_action(state)
        new_state, reward, done, _ = env.step(action)
        log_probs.append(log_prob)
        rewards.append(reward)

        if done:
            update_policy(policy_net, rewards, log_probs)
            numsteps.append(steps)
            avg_numsteps.append(np.mean(numsteps[-10:]))
            all_rewards.append(np.sum(rewards))
            if episode % 10 == 0:
                sys.stdout.write("episode: {}, total reward: {}, average_reward: {}, length: {}\n".format(episode, np.round(np.sum(rewards), decimals = 3),  np.round(np.mean(all_rewards[-10:]), decimals = 3), steps))
            break
            
        state = new_state
# Out:
# episode: 0, total reward: 28.0, average_reward: 28.0, length: 27
# episode: 10, total reward: 19.0, average_reward: 20.5, length: 18
# episode: 20, total reward: 30.0, average_reward: 22.7, length: 29
# episode: 30, total reward: 19.0, average_reward: 40.9, length: 18
# episode: 40, total reward: 36.0, average_reward: 33.6, length: 35
# episode: 50, total reward: 17.0, average_reward: 25.4, length: 16
# episode: 60, total reward: 30.0, average_reward: 22.8, length: 29
# episode: 70, total reward: 30.0, average_reward: 25.1, length: 29
# episode: 80, total reward: 33.0, average_reward: 22.8, length: 32
# episode: 90, total reward: 21.0, average_reward: 20.9, length: 20
# episode: 2580, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2590, total reward: 200.0, average_reward: 198.6, length: 199
# episode: 2600, total reward: 200.0, average_reward: 197.4, length: 199
# episode: 2610, total reward: 200.0, average_reward: 198.2, length: 199
# episode: 2620, total reward: 200.0, average_reward: 189.2, length: 199
# episode: 2630, total reward: 200.0, average_reward: 183.4, length: 199
# episode: 2640, total reward: 200.0, average_reward: 172.7, length: 199
# episode: 2650, total reward: 188.0, average_reward: 196.5, length: 187
# episode: 2660, total reward: 200.0, average_reward: 173.9, length: 199
# episode: 2670, total reward: 200.0, average_reward: 186.2, length: 199
# episode: 2680, total reward: 200.0, average_reward: 191.5, length: 199
# episode: 2690, total reward: 184.0, average_reward: 186.6, length: 183
# episode: 2700, total reward: 172.0, average_reward: 182.3, length: 171
# episode: 2710, total reward: 200.0, average_reward: 189.1, length: 199
# episode: 2720, total reward: 200.0, average_reward: 174.0, length: 199
# episode: 2730, total reward: 200.0, average_reward: 191.5, length: 199
# episode: 2740, total reward: 200.0, average_reward: 188.0, length: 199
# episode: 2750, total reward: 141.0, average_reward: 181.8, length: 140
# episode: 2760, total reward: 200.0, average_reward: 186.6, length: 199
# episode: 2770, total reward: 200.0, average_reward: 190.5, length: 199
# episode: 2780, total reward: 200.0, average_reward: 196.5, length: 199
# episode: 2790, total reward: 200.0, average_reward: 175.4, length: 199
# episode: 2800, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2810, total reward: 200.0, average_reward: 198.4, length: 199
# episode: 2820, total reward: 200.0, average_reward: 175.7, length: 199
# episode: 2830, total reward: 200.0, average_reward: 198.0, length: 199
# episode: 2840, total reward: 200.0, average_reward: 197.3, length: 199
# episode: 2850, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2860, total reward: 200.0, average_reward: 199.6, length: 199
# episode: 2870, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2880, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2890, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2900, total reward: 200.0, average_reward: 186.5, length: 199
# episode: 2910, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2920, total reward: 200.0, average_reward: 194.5, length: 199
# episode: 2930, total reward: 127.0, average_reward: 190.0, length: 126
# episode: 2940, total reward: 200.0, average_reward: 192.1, length: 199
# episode: 2950, total reward: 200.0, average_reward: 196.3, length: 199
# episode: 2960, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2970, total reward: 200.0, average_reward: 193.0, length: 199
# episode: 2980, total reward: 200.0, average_reward: 200.0, length: 199
# episode: 2990, total reward: 200.0, average_reward: 200.0, length: 199

# %%
smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
plt.plot(all_rewards)
plt.plot(avg_numsteps)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()
print('Varince of reward = {}'.format(np.var(all_rewards)))
# Out:
# Varince of reward = 4152.068191

# %%
df = pd.DataFrame()
df['rewards'] = all_rewards
df['mean10_rewards'] = avg_numsteps

# %%
df.to_csv('D:/Reinforcement_Learning/df_reinforce.csv', index=False)
